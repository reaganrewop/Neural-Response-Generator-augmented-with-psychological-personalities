# %%
import sys
sys.path.append("/dbfs/grimlock/sri/sidework/")

root_path = "/dbfs/grimlock/sri/sidework/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pandas as pd
import autoreload
import sys
sys.path.append(root_path + "library/")

# %load_ext autoreload
# %autoreload 2

# Data preprocessing custom package
import text_preprocessing
from text_preprocessing import Preprocessor

pt = Preprocessor()

# essentials
import numpy as np
from tqdm import tqdm
import pickle
import pickle as pkl
from scipy import sparse
from numpy import asarray
from numpy import savetxt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[nltk_data] Downloading package wordnet to /tmp/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /tmp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /tmp/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /tmp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# </div>

# %%
import numpy as np
import pickle

# To read the files
X_train, X_val, y_train, y_val = np.load(open(root_path + "data/intermediate/MBTI_datasplit_v2.pkl", "rb"))
data = pickle.load(open(root_path + "data/intermediate/MBTI_data_before_split_v2.pkl", "rb"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # End of Data Engineering

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from collections import Counter
import numpy as np

def list_to_bow(l_words):
    """
    This function takes a list of words and create the bag of words ordered by desc order
    """
    cv = CountVectorizer(l_words)
    # show resulting vocabulary; the numbers are not counts, they are the position in the sparse vector.
    count_vector=cv.fit_transform(l_words)
    word_freq = Counter(l_words)
    print(f"Bag of words size: {count_vector.shape}\nUnique words size: {len(word_freq)}")
    dict_word_freq = dict(word_freq.most_common())
    return(dict_word_freq)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#X_train_oneshot = list_to_bow(data.loc[X_train]['post'])
import nltk

word_tokenized = []
for sent in pt.get_tokenized_sent(" ".join(data.loc[X_train]['post'])):
  word_tokenized.extend(nltk.word_tokenize(sent))
  
X_train_oneshot = list_to_bow(word_tokenized)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Bag of words size: (7983656, 85559)
# Unique words size: 143901
# </div>

# %%
#X_train_oneshot = list_to_bow(data.loc[X_train]['post'])
import nltk

word_tokenized = []
for sent in pt.get_tokenized_sent(" ".join(data.loc[X_train]['post'])):
  word_tokenized.extend(nltk.word_tokenize(sent))
  
X_train_oneshot = list_to_bow(word_tokenized)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass input=[&#39;I&#39;, &#39;have&#39;, &#39;never&#39;, &#39;posted&#39;, &#39;my&#39;, &#39;picture&#39;, &#39;online&#39;, &#39;to&#39;, &#39;be&#39;, &#39;measure&#39;, &#39;by&#39;, &#39;the&#39;, &#39;beauty&#39;, &#39;standard&#39;, &#39;that&#39;, &#39;others&#39;, &#39;have&#39;, &#39;.&#39;, &#39;Human&#39;, &#39;bodies&#39;, &#39;comes&#39;, &#39;in&#39;, &#39;all&#39;, &#39;sizes&#39;, &#39;and&#39;, &#39;shapes&#39;, &#39;.&#39;, &#39;No&#39;, &#39;matter&#39;, &#39;who&#39;, &#39;you&#39;, &#39;are&#39;, &#39;there&#39;, &#39;is&#39;, &#39;someone&#39;, &#39;that&#39;, &#39;will&#39;, &#39;find&#39;, &#39;your&#39;, &#39;...&#39;, &#39;When&#39;, &#39;I&#39;, &#39;said&#39;, &#39;young&#39;, &#39;I&#39;, &#39;meant&#39;, &#39;midtwenties&#39;, &#39;.&#39;, &#39;You&#39;, &#39;did&#39;, &#39;not&#39;, &#39;sounds&#39;, &#39;like&#39;, &#39;a&#39;, &#39;highschooler&#39;, &#39;.&#39;, &#39;I&#39;, &#39;appreciate&#39;, &#39;your&#39;, &#39;emotional&#39;, &#39;maturity&#39;, &#39;because&#39;, &#39;of&#39;, &#39;life&#39;, &#39;circumstance&#39;, &#39;and&#39;, &#39;personality&#39;, &#39;type&#39;, &#39;.&#39;, &#39;INFJs&#39;, &#39;tend&#39;, &#39;to&#39;, &#39;be&#39;, &#39;emotionally&#39;, &#39;...&#39;, &#39;My&#39;, &#39;thoughts&#39;, &#39;exactly&#39;, &#39;.&#39;, &#39;Cept&#39;, &#39;I&#39;, &#39;am&#39;, &#39;in&#39;, &#39;my&#39;, &#39;early&#39;, &#39;s&#39;, &#39;and&#39;, &#39;I&#39;, &#39;do&#39;, &#39;enjoy&#39;, &#39;myself&#39;, &#39;a&#39;, &#39;few&#39;, &#39;onenighters&#39;, &#39;here&#39;, &#39;and&#39;, &#39;there&#39;, &#39;.&#39;, &#39;Oh&#39;, &#39;well&#39;, &#39;sue&#39;, &#39;me&#39;, &#39;.&#39;, &#39;I&#39;, &#39;like&#39;, &#39;no&#39;, &#39;strings&#39;, &#39;attached&#39;, &#39;sex&#39;, &#39;.&#39;, &#39;Its&#39;, &#39;fun&#39;, &#39;and&#39;, &#39;simple&#39;, &#39;.&#39;, &#39;Maybe&#39;, &#39;I&#39;, &#39;will&#39;, &#39;care&#39;, &#39;more&#39;, &#39;...&#39;, &#39;Enlightenment&#39;, &#39;is&#39;, &#39;a&#39;, &#39;way&#39;, &#39;of&#39;, &#39;life&#39;, &#39;a&#39;, &#39;practice&#39;, &#39;is&#39;, &#39;not&#39;, &#39;it&#39;, &#39;emojiemoji&#39;, &#39;Maybe&#39;, &#39;we&#39;, &#39;can&#39;, &#39;discuss&#39;, &#39;all&#39;, &#39;of&#39;, &#39;this&#39;, &#39;sometime&#39;, &#39;xoxo&#39;, &#39;Miranda&#39;, &#39;INFJ&#39;, &#39;I&#39;, &#39;really&#39;, &#39;like&#39;, &#39;spending&#39;, &#39;time&#39;, &#39;with&#39;, &#39;TPs&#39;, &#39;but&#39;, &#39;also&#39;, &#39;feel&#39;, &#39;drawn&#39;, &#39;to&#39;, &#39;FJs&#39;, &#39;.&#39;, &#39;I&#39;, &#39;would&#39;, &#39;be&#39;, &#39;fine&#39;, &#39;with&#39;, &#39;either&#39;, &#39;as&#39;, &#39;long&#39;, &#39;as&#39;, &#39;they&#39;, &#39;were&#39;, &#39;equal&#39;, &#39;to&#39;, &#39;or&#39;, &#39;greater&#39;, &#39;than&#39;, &#39;me&#39;, &#39;in&#39;, &#39;intelligence&#39;, &#39;.&#39;, &#39;FPs&#39;, &#39;would&#39;, &#39;not&#39;, &#39;be&#39;, &#39;bad&#39;, &#39;either&#39;, &#39;I&#39;, &#39;suppose&#39;, &#39;....&#39;, &#39;Smiles&#39;, &#39;and&#39;, &#39;cracks&#39;, &#39;knuckles&#39;, &#39;Haha&#39;, &#39;just&#39;, &#39;kidding&#39;, &#39;around&#39;, &#39;.&#39;, &#39;But&#39;, &#39;in&#39;, &#39;addition&#39;, &#39;to&#39;, &#39;my&#39;, &#39;complete&#39;, &#39;agreement&#39;, &#39;with&#39;, &#39;your&#39;, &#39;observations&#39;, &#39;in&#39;, &#39;your&#39;, &#39;first&#39;, &#39;paragraph&#39;, &#39;especially&#39;, &#39;the&#39;, &#39;part&#39;, &#39;about&#39;, &#39;Dick&#39;, &#39;and&#39;, &#39;Bruce&#39;, &#39;being&#39;, &#39;...&#39;, &#39;My&#39;, &#39;older&#39;, &#39;brother&#39;, &#39;was&#39;, &#39;diagnosed&#39;, &#39;with&#39;, &#39;this&#39;, &#39;.&#39;, &#39;I&#39;, &#39;am&#39;, &#39;.&#39;, &#39;Having&#39;, &#39;lived&#39;, &#39;with&#39;, &#39;him&#39;, &#39;for&#39;, &#39;over&#39;, &#39;years&#39;, &#39;I&#39;, &#39;can&#39;, &#39;safely&#39;, &#39;sa ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = data['post']
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(corpus)

dictionary = dict(zip(vectorizer.get_feature_names(), tfidf))

with open(root_path + "data/intermediate/tfidf.pkl", 'wb') as handle:
    pickle.dump(tfidf, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
tfidf_df = pd.DataFrame(tfidf)
tfidf_df.to_csv(root_path + "data/intermediate/tfidf.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print (tfidf.shape)
print (len(dictionary))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(258129, 92893)
# 92893
# </div>

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.manifold import TSNE

svd = TruncatedSVD(n_components=100, n_iter=10, random_state=42)
svd_vec = svd.fit_transform(tfidf)

print("TSNE")
X_tsne = TSNE(n_components=3, verbose=1, perplexity=40).fit_transform(svd_vec)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">TSNE
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 258129 samples in 3.657s...
# [t-SNE] Computed neighbors for 258129 samples in 30003.179s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 258129
# [t-SNE] Computed conditional probabilities for sample 2000 / 258129
# [t-SNE] Computed conditional probabilities for sample 3000 / 258129
# [t-SNE] Computed conditional probabilities for sample 4000 / 258129
# [t-SNE] Computed conditional probabilities for sample 5000 / 258129
# [t-SNE] Computed conditional probabilities for sample 6000 / 258129
# [t-SNE] Computed conditional probabilities for sample 7000 / 258129
# [t-SNE] Computed conditional probabilities for sample 8000 / 258129
# [t-SNE] Computed conditional probabilities for sample 9000 / 258129
# [t-SNE] Computed conditional probabilities for sample 10000 / 258129
# [t-SNE] Computed conditional probabilities for sample 11000 / 258129
# [t-SNE] Computed conditional probabilities for sample 12000 / 258129
# [t-SNE] Computed conditional probabilities for sample 13000 / 258129
# [t-SNE] Computed conditional probabilities for sample 14000 / 258129
# [t-SNE] Computed conditional probabilities for sample 15000 / 258129
# [t-SNE] Computed conditional probabilities for sample 16000 / 258129
# [t-SNE] Computed conditional probabilities for sample 17000 / 258129
# [t-SNE] Computed conditional probabilities for sample 18000 / 258129
# [t-SNE] Computed conditional probabilities for sample 19000 / 258129
# [t-SNE] Computed conditional probabilities for sample 20000 / 258129
# [t-SNE] Computed conditional probabilities for sample 21000 / 258129
# [t-SNE] Computed conditional probabilities for sample 22000 / 258129
# [t-SNE] Computed conditional probabilities for sample 23000 / 258129
# [t-SNE] Computed conditional probabilities for sample 24000 / 258129
# [t-SNE] Computed conditional probabilities for sample 25000 / 258129
# [t-SNE] Computed conditional probabilities for sample 26000 / 258129
# [t-SNE] Computed conditional probabilities for sample 27000 / 258129
# [t-SNE] Computed conditional probabilities for sample 28000 / 258129
# [t-SNE] Computed conditional probabilities for sample 29000 / 258129
# [t-SNE] Computed conditional probabilities for sample 30000 / 258129
# [t-SNE] Computed conditional probabilities for sample 31000 / 258129
# [t-SNE] Computed conditional probabilities for sample 32000 / 258129
# [t-SNE] Computed conditional probabilities for sample 33000 / 258129
# [t-SNE] Computed conditional probabilities for sample 34000 / 258129
# [t-SNE] Computed conditional probabilities for sample 35000 / 258129
# [t-SNE] Computed conditional probabilities for sample 36000 / 258129
# [t-SNE] Computed conditional probabilities for sample 37000 / 258129
# [t-SNE] Computed conditional probabilities for sample 38000 / 258129
# [t-SNE] Computed conditional probabilities for sample 39000 / 258129
# [t-SNE] Computed conditional probabilities for sample 40000 / 258129
# [t-SNE] Computed conditional probabilities for sample 41000 / 258129
# [t-SNE] Computed conditional probabilities for sample 42000 / 258129
# [t-SNE] Computed conditional probabilities for sample 43000 / 258129
# [t-SNE] Computed conditional probabilities for sample 44000 / 258129
# [t-SNE] Computed conditional probabilities for sample 45000 / 258129
# [t-SNE] Computed conditional probabilities for sample 46000 / 258129
# [t-SNE] Computed conditional probabilities for sample 47000 / 258129
# [t-SNE] Computed conditional probabilities for sample 48000 / 258129
# [t-SNE] Computed conditional probabilities for sample 49000 / 258129
# [t-SNE] Computed conditional probabilities for sample 50000 / 258129
# [t-SNE] Computed conditional probabilities for sample 51000 / 258129
# [t-SNE] Computed conditional probabilities for sample 52000 / 258129
# [t-SNE] Computed conditional probabilities for sample 53000 / 258129
# [t-SNE] Computed conditional probabilities for sample 54000 / 258129
# [t-SNE] Computed conditional probabilities for sample 55000 / 258129
# [t-SNE] Computed conditional probabilities for sample 56000 / 258129
# [t-SNE] Computed conditional probabilities for sample 57000 / 258129
# [t-SNE] Computed conditional probabilities for sample 58000 / 258129
# [t-SNE] Computed conditional probabilities for sample 59000 / 258129
# [t-SNE] Computed conditional probabilities for sample 60000 / 258129
# [t-SNE] Computed conditional probabilities for sample 61000 / 258129
# [t-SNE] Computed conditional probabilities for sample 62000 / 258129
# [t-SNE] Computed conditional probabilities for sample 63000 / 258129
# [t-SNE] Computed conditional probabilities for sample 64000 / 258129
# [t-SNE] Computed conditional probabilities for sample 65000 / 258129
# [t-SNE] Computed conditional probabilities for sample 66000 / 258129
# [t-SNE] Computed conditional probabilities for sample 67000 / 258129
# [t-SNE] Computed conditional probabilities for sample 68000 / 258129
# [t-SNE] Computed conditional probabilities for sample 69000 / 258129
# [t-SNE] Computed conditional probabilities for sample 70000 / 258129
# [t-SNE] Computed conditional probabilities for sample 71000 / 258129
# [t-SNE] Computed conditional probabilities for sample 72000 / 258129
# [t-SNE] Computed conditional probabilities for sample 73000 / 258129
# [t-SNE] Computed conditional probabilities for sample 74000 / 258129
# [t-SNE] Computed conditional probabilities for sample 75000 / 258129
# [t-SNE] Computed conditional probabilities for sample 76000 / 258129
# [t-SNE] Computed conditional probabilities for sample 77000 / 258129
# [t-SNE] Computed conditional probabilities for sample 78000 / 258129
# [t-SNE] Computed conditional probabilities for sample 79000 / 258129
# [t-SNE] Computed conditional probabilities for sample 80000 / 258129
# [t-SNE] Computed conditional probabilities for sample 81000 / 258129
# [t-SNE] Computed conditional probabilities for sample 82000 / 258129
# [t-SNE] Computed conditional probabilities for sample 83000 / 258129
# [t-SNE] Computed conditional probabilities for sample 84000 / 258129
# [t-SNE] Computed conditional probabilities for sample 85000 / 258129
# [t-SNE] Computed conditional probabilities for sample 86000 / 258129
# [t-SNE] Computed conditional probabilities for sample 87000 / 258129
# [t-SNE] Computed conditional probabilities for sample 88000 / 258129
# [t-SNE] Computed conditional probabilities for sample 89000 / 258129
# [t-SNE] Computed conditional probabilities for sample 90000 / 258129
# [t-SNE] Computed conditional probabilities for sample 91000 / 258129
# [t-SNE] Computed conditional probabilities for sample 92000 / 258129
# [t-SNE] Computed conditional probabilities for sample 93000 / 258129
# [t-SNE] Computed conditional probabilities for sample 94000 / 258129
# [t-SNE] Computed conditional probabilities for sample 95000 / 258129
# [t-SNE] Computed conditional probabilities for sample 96000 / 258129
# [t-SNE] Computed conditional probabilities for sample 97000 / 258129
# [t-SNE] Computed conditional probabilities for sample 98000 / 258129
# [t-SNE] Computed conditional probabilities for sample 99000 / 258129
# [t-SNE] Computed conditional probabilities for sample 100000 / 258129
# [t-SNE] Computed conditional probabilities for sample 101000 / 258129
# [t-SNE] Computed conditional probabilities for sample 102000 / 258129
# [t-SNE] Computed conditional probabilities for sample 103000 / 258129
# [t-SNE] Computed conditional probabilities for sample 104000 / 258129
# [t-SNE] Computed conditional probabilities for sample 105000 / 258129
# [t-SNE] Computed conditional probabilities for sample 106000 / 258129
# [t-SNE] Computed conditional probabilities for sample 107000 / 258129
# [t-SNE] Computed conditional probabilities for sample 108000 / 258129
# [t-SNE] Computed conditional probabilities for sample 109000 / 25

# %%
x_tnse
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-7420091&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>x_tnse
#
# <span class="ansi-red-fg">NameError</span>: name &#39;x_tnse&#39; is not defined</div>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_validate
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.feature_extraction.text import HashingVectorizer

print ("Starting to Vectorize")
#vectorizer = HashingVectorizer(ngram_range=(1,2), n_features=10000)
vectorizer = HashingVectorizer(ngram_range=(1,2), n_features=100)
X_train_oneshot = vectorizer.transform(train_data.loc[X_train]['post']).toarray()

X_val_oneshot = vectorizer.transform(train_data.loc[X_val]['post']).toarray()

print ("Vectorization done")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Starting to Vectorize
# Vectorization done
# </div>

# %%
from sklearn.linear_model import BayesianRidge

reg = BayesianRidge(n_iter=300, normalize=True, verbose=True)
reg.fit(X_train_oneshot, y_train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Convergence after  23  iterations
# Out[13]: BayesianRidge(normalize=True, verbose=True)</div>

# %%
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

score = reg.score(X_train_oneshot, y_train)
print("Model score (R-squared): %.2f" % score)

ypred = reg.predict(X_val_oneshot)
mse = mean_squared_error(ypred, y_val)
print("MSE: %.2f" % mse)
 
print("RMSE: %.2f" % (mse**0.5))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Model score (R-squared): 0.07
# MSE: 10.80
# RMSE: 3.29
# </div>

# %%
x_ax = range(len(y_val))
plt.scatter(x_ax, y_val, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %% [markdown]
# # generic basline comparison

# %%
train_data = pd.read_pickle(root_path + "data/processed/MBTI_preprocessed_v3.pkl")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# split and vectorize

from tqdm.notebook import tqdm

labels = train_data['type'].unique()

label_dict = {}
for index, label in enumerate(labels):
    label_dict[label] = index
    
train_data['label'] = train_data['type'].replace(label_dict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(train_data.index.values, 
                                                  train_data.label.values, 
                                                  test_size=0.2, 
                                                  random_state=42,
                                                  stratify=train_data.label.values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print (X_train.shape, "\n", y_train.shape, "\n", X_val.shape, "\n", y_val.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(206503,)
#  (206503,)
#  (51626,)
#  (51626,)
# </div>

# %%
def model_comparison(model, X_train, X_test, y_train, y_test, name):
    strat_k_fold = StratifiedKFold(n_splits=5, shuffle=True)
    model.fit(X_train, y_train)
    accuracy     = np.mean(cross_val_score(model, X_train, y_train, cv=strat_k_fold, scoring='accuracy'))
    precision    = np.mean(cross_val_score(model, X_train, y_train, cv=strat_k_fold, scoring='precision_weighted'))
    recall       = np.mean(cross_val_score(model, X_train, y_train, cv=strat_k_fold, scoring='recall_weighted'))
    f1score      = np.mean(cross_val_score(model, X_train, y_train, cv=strat_k_fold, scoring='f1_weighted'))
    y_pred = model.predict(X_test)
    mcm = multilabel_confusion_matrix(y_test, y_pred)
    tn = mcm[:, 0, 0]
    tp = mcm[:, 1, 1]
    fn = mcm[:, 1, 0]
    fp = mcm[:, 0, 1]
    specificities = tn / (tn+fp)
    specificity = (specificities.sum())/ 16

    df_model = pd.DataFrame({'model'        : [name],
                             'accuracy'     : [accuracy],
                             'precision'    : [precision],
                             'recall'       : [recall],
                             'f1score'      : [f1score],
                             'specificity'  : [specificity]
                            })
    print ("done with: ", name)
    return df_model
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score

#Metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, multilabel_confusion_matrix

#basic
import numpy as np

# models = {'gnb': GaussianNB(),
#           'logit': LogisticRegression(),
#           'knn': KNeighborsClassifier(),
#           'decisiontree': DecisionTreeClassifier(),
#           'randomforest': RandomForestClassifier(),
#           'xgboost': GradientBoostingClassifier(),
#           'MLPC': MLPClassifier()
#          }
models = {'gnb': GaussianNB(),
          #'logit': LogisticRegression(),
          #'knn': KNeighborsClassifier(),
          #'decisiontree': DecisionTreeClassifier(),
          #'randomforest': RandomForestClassifier(),
          'xgboost': GradientBoostingClassifier()
          #'MLPC': MLPClassifier()
         }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.feature_extraction.text import HashingVectorizer

print ("Starting to Vectorize")
vectorizer = HashingVectorizer(ngram_range=(1,3), n_features=100)

X_train_oneshot = vectorizer.transform(train_data.loc[X_train]['post']).toarray()

X_val_oneshot = vectorizer.transform(train_data.loc[X_val]['post']).toarray()

print ("Vectorization done")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Starting to Vectorize
# Vectorization done
# </div>

# %%
models_svd = pd.concat([model_comparison(model, X_train_oneshot, X_val_oneshot, y_train, y_val, name) for (name, model) in models.items()])
#models_svd.to_csv("models_svd.csv")
models_svd
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1score</th>
#       <th>specificity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gnb</td>
#       <td>0.208055</td>
#       <td>0.159612</td>
#       <td>0.207329</td>
#       <td>0.145910</td>
#       <td>0.939137</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>xgboost</td>
#       <td>0.210680</td>
#       <td>0.173301</td>
#       <td>0.211188</td>
#       <td>0.115134</td>
#       <td>0.938370</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model_svd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print ("hello")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
